# %% [markdown]
# <a href="https://colab.research.google.com/github/datawilly/procesamiento-de-datos/blob/main/ROSALES_WILLIAM_PEC_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a name = "inicio"></a>
# ![image-2.png](attachment:image-2.png)
# <p style="text-align:center;font-size:30px;font-weight: bold;">PRUEBA DE EVALUACIÓN CONTINUA</p>

# %% [markdown]
# # Objetivos
#
# El objetivo de esta PEC es evaluar el conocimiento del alumno en el uso de las librerías de Python **NumPy**, **pandas**, **matplotlib** y **Seaborn**, aplicándolas en la visualización y transformación de conjuntos de datos.
#
# La prueba consta de tres bloques de preguntas correspondientes a tres niveles de dificultad:
#
# * **Nivel básico**, en las que el alumno deberá ser capaz de realizar tareas, ejercicios o prácticas similares a las aprendidas en la documentación del módulo.
# * **Nivel intermedio**, en las que el alumno deberá ser capaz de aplicar las técnicas, conocimientos y habilidades revisadas en la documentación a problemas con elementos diferentes.
# * **Nivel avanzado**, en las que el alumno deberá ser capaz de amplicar las técnicas, conocimientos y habilidades aprendidas investigando nuevos aspectos, problemas o elementos.

# %% [markdown]
# # Importante
#
# * El alumno deberá completar este cuaderno sin modificar las preguntas ni modificar la estructura del propio cuaderno (se pueden añadir celdas, pero no modificar ni eliminar las existentes)
# * El entregable será el cuaderno Jupyter (no ficheros planos con código python, ni PDF's ni material en ningún otro soporte)
# * El cuaderno Jupyter con las respuestas deberá poder ser reejecutado sin que se produzca ningún error
# * Salvo que se pida lo contrario, no se cargará ningún fichero desde el equipo local. Si se pide cargar una imagen y se indica la url de la que descargarla, esto podrá hacerse copiando la url, pegándola en la barra de direcciones de un navegador, haciendo clic con el botón secundario del ratón en la imagen y seleccionando la opción que la descargue (esta opción dependerá del navegador que se esté usando). En este caso la imagen deberá descargarse en la misma carpeta en la que esté este cuaderno Jupyter.
# * Salvo que se especifique otra cosa, deberán utilizarse siempre las herramientas proveídas por las librerías NumPy, Pandas, Seaborn o Matplotlib. No puede recurrirse a otras librerías.
# * Salvo que se indique lo contrario, en cada ejercicio deberán cargarse los datos necesarios aun cuando hayan sido cargados en ejercicios anteriores (es decir, si el ejercicio hace referencia al DataFrame Tips de Seaborn, salvo que se especifique otra cosa lo primero que deberá hacerse es cargar dicho DataFrame, aun cuando haya sido cargado ya en un ejercicio anterior).
#
# El incumplimiento de cualquiera de estas normal supondrá la invalidación del ejercicio o del apartado correspondiente.
#
# Todos los ejercicios tienen el mismo valor (un punto).

# %% [markdown]
# * [NIVEL BÁSICO: 5 puntos](#NIVEL-BÁSICO:-5-puntos)
# * [NIVEL INTERMEDIO: 3 puntos](#NIVEL-INTERMEDIO:-3-puntos)
# * [NIVEL AVANZADO: 2 puntos](#NIVEL-AVANZADO:-2-puntos)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # NIVEL BÁSICO: 5 puntos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ### Ejercicio 1
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# Fija la semilla del generador de números aleatorios de NumPy con el valor 18, genera un array unidimensional de 5 valores extraídos de una distribución gaussiana de media 10 y desviación estándar 2 y asígnalo a la variable <strong>a</strong>.
# </div>

# %% [markdown]
# **Linea 1:** Para poder fijar la semilla del generador de numeros aleatorios usamos la funcion **np.random.seed()** y le asignamos el valor de 18.
#
# **Linea 2:** Establecemos la variable *media*.
#
# **Linea 3:** Establecemos la variable *desviacion*.
#
# **Linea 4:** Generamos nuestro array con **np.random.normal()** y le asignamos los parametros *loc* para la media, *scale* para la desviacion y *size* para el numero de elementos.

# %%
np.random.seed(18)
media = 10
desviacion = 2
a = np.random.normal(loc=media, scale=desviacion, size=5)

# %% [markdown]
# <div style="background:#D8D8D8;padding:20px;color:#000000;margin-top:10px;">
# Prueba ahora tu solución ejecutando la siguiente celda:
# </div>

# %%
print(a)
# Out:
# [10.15885689 14.38040471  9.73021571 10.32103596 10.88539569]

# %% [markdown]
# ### Ejercicio 2
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# Muestra un diagrama de tarta a partir del array obtenido en el ejercicio anterior. Muestra para cada segmento el valor que representa.
# </div>

# %% [markdown]
# **Linea 1:** Convertimos nuestro array en una serie de pandas.
#
# **Linea 2:** Generamos la figura y los ejes con **plt.subplots()** y establecemos el tamaño de la figura.
#
# **Linea 3:** Creamos el gráfico usando el método **.pie**, le agregamos los labels que van a ser los valores de la serie y con *autopct* le pedimos que nos de el porcentaje que ocupan del gráfico.

# %%
a = pd.Series(a)
fig, ax = plt.subplots(figsize=(10,5))
ax.pie(a, labels = a, autopct = '%.2f%%')
plt.show()

# %% [markdown]
# ### Ejercicio 3
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# Carga en la variable <strong>tips</strong> el DataFrame tips de la librería Seaborn y sustituye todos los valores del campo "tip" que sean menores que 2 por un NaN.
# </div>

# %% [markdown]
# **Linea 1:** Cargamos la libreria tips desde Seaborn.
#
# **Linea 2:** Mostramos el dataset original.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Linea 1:** Usamos **np.where()** para seleccionar de la columna tips los valores *menores* a 2 y los reemplaze con **np.NaN** (*es importante que sea así ya que si pasamos directamente la cadena **NaN** lo va a guardar como cadena y no va a contarse*) y si el valor es mayor o igual a 2 lo deja igual.
#
# **Linea 2:** Mostramos el dataset para visualizar el cambio.

# %%
tips["tip"] = np.where(tips["tip"] < 2, np.NaN , tips["tip"])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99   NaN  Female     No  Sun  Dinner     2
# 1       10.34   NaN    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <div style="background:#D8D8D8;padding:20px;color:#000000;margin-top:10px;">
# Prueba ahora tu solución ejecutando la siguiente celda:
# </div>

# %%
tips.tip.isna().sum()
# Out:
# 45

# %% [markdown]
# ### Ejercicio 4
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# Carga en la variable <strong>tips</strong> el DataFrame tips proveído por la librería Seaborn. Usando únicamente funciones de matplotlib, crea una figura de tamaño (8, 6) y muestra en ella un diagrama de dispersión que cruce las columnas "tip" y "total_bill" del dataset tips.
# </div>

# %% [markdown]
# **Linea 1:** Cargamos el dataset tips de Seaborn.
#
# **Linea 2:** Generamos la figura y los ejes y le asignamos el tamaño 8,6 en pulgadas.
#
# **Linea 3:** Fijamos el título de nuestro grafico.
#
# **Linea 4:** Usamos el tipo de grafico método **scatter()**, le asignamos el eje *x* para tip y el eje *y* para total bill y cambiamos el tamaño de los puntos a 10 para una mejor visualizacion.
#
# **Linea 5:** Fijamos la etiqueta para el eje *x*.
#
# **Linea 6:** Fijamos la etiqueta par el eje *y*.

# %%
tips = sns.load_dataset("tips")
fig, ax = plt.subplots(figsize = (8,6))
ax.set_title("Tip Vs Total Bill")
ax.scatter(tips.tip,tips.total_bill, s = 10)
ax.set_xlabel("Tip")
ax.set_ylabel("Total Bill")
plt.show()

# %% [markdown]
# ### Ejercicio 5
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
#     Descarga a tu ordenador la imagen cuya url se muestra a continuación y léela con matplotlib en la variable "sunset". Modifica la capa de transparencia (la última capa) de forma que una franja horizontal (límites a escoger por el alumno) se muestre semitransparente (para lo que se sugiere sustituir los valores de dicha franja por el valor 0.5). La franja horizontal deberá dejar una zona sin modificar tanto por encima como por debajo (es decir, la franja no puede ocupar toda la imagen).
# </div>

# %%
url = "https://www.interactivechaos.com/data/sunset.png"

# %% [markdown]
# **Linea 1:** Leemos la imagen descargada desde la url.
#
# **Linea 2:** Modificamos el array resultante de la lectura de la imagen seleccionando el array del eje *y* los cuales correspondan entre los pixeles 200 y 300, los del eje *x* los seleccionamos todos y le aplicamos a la cuarta capa el valor 0.5.

# %%
sunset = plt.imread("sunset.png")
sunset[200:300,:,3] = 0.5

# %% [markdown]
# <div style="background:#D8D8D8;padding:20px;color:#000000;margin-top:10px;">
# Prueba ahora tu solución ejecutando la siguiente celda:
# </div>

# %%
plt.imshow(sunset)
plt.show()

# %% [markdown]
# # NIVEL INTERMEDIO: 3 puntos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ### Ejercicio 1
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# Escribe una función (llámala "nulls_number") que reciba como argumento un DataFrame Pandas, obtenga las 5 columnas con mayor número de valores nulos y devuelva una serie Pandas conteniendo los nombres de dichas columnas como índices y el número de nulos como valores.
# </div>

# %% [markdown]
# **Linea 1:** Definimos la funcion *nulls_number* que recibe como parametro un dataframe.
#
# **Linea 2:** A este dataframe le vamos a contar los valores nulos, los sumamos y lo guardamos en la misma variable, esta vez como una serie pandas.
#
# **Linea 3:** Ordenamos los valores de esta serie en forma descendente para obtener los que tengan mayor numero de nulos y sobreescribimos la serie.
#
# **Linea 4:** Mostramos los primeros 5 valores de la serie y volvemos a sobreescribir la variable.

# %%
def nulls_number(df):
    df = df.isnull().sum()
    df = df.sort_values(ascending = False)
    df = df.head()
    return df

# %% [markdown]
# <div style="background:#D8D8D8;padding:20px;color:#000000;margin-top:10px;">
# Prueba ahora tu solución ejecutando la siguiente celda:
# </div>

# %%
titanic = sns.load_dataset("titanic")
nulls_number(titanic)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# dtype: int64

# %% [markdown]
# ### Ejercicio 2
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# A partir del DataFrame Titanic descargado de la librería Seaborn y creando una tabla dinámica a partir de él, responde a la siguiente pregunta: ¿En qué puerto los hombres y las mujeres de alguna clase (primera, segunda o tercera) pagaron en media exactamente lo mismo por su pasaje?
# </div>

# %% [markdown]
# **Linea 1:** Cargamos el dataset titanic de Seaborn.
#
# **Linea 2:** Usamos la funcion **pivot_table()** para generar una tabla dinamica que tenga como filas la ciudad de embarque y el sexo, las columnas van a ser la clase, como valores vamos a tomar la tarifa y como funcion agregadora seleccionamos la media, todo esto lo guardamos en una nueva variable llamada titanic2 para no modificar la original.

# %%
titanic = sns.load_dataset("titanic")
titanic2 = titanic.pivot_table(index = ["embark_town","sex"], columns = ["class"], values = ["fare"])
titanic2
# Out:
#                           fare
# class                    First     Second      Third
# embark_town sex
# Cherbourg   female  115.640309  25.268457  14.694926
#             male     93.536707  25.421250   9.352237
# Queenstown  female   90.000000  12.350000  10.307833
#             male     90.000000  12.350000  11.924251
# Southampton female   99.026910  21.912687  18.670077
#             male     52.949947  19.232474  13.307149

# %% [markdown]
# **Respuesta:** En el puerto de Queenstown los hombres y mujeres de **primera** y **segunda** clase pagaron exactamente el mismo pasaje en cada una de sus clases.

# %% [markdown]
# ### Ejercicio 3
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# A partir del DataFrame Titanic descargado de la librería Seaborn y creando una única figura, muestra dos gráficas situadas horizontalmente: la de la izquierda deberá ser una gráfica de columnas (realizada con matplotlib) con el número de pasajeros embarcados en cada puerto, y la de la derecha deberá ser un gráfico de violín (realizado con seaborn) con la distribución de la edad en función del sexo del pasajero.
# </div>

# %% [markdown]
# **Linea 1:** Cargamos el dataset titanic de la libreria Seaborn.
#
# **Linea 2:** Generamos la figura y los ejes, en este caso van a ser 2 columnas y 1 fila.
#
# **Linea 3:** Seleccionamos el primer conjunto de ejes e incluimos un grafico de barras con matplotlib que nos muestre en el eje *x* los nombres de las ciudades que fueron puertos de embarque y en el eje *y* el conteo de valores de cada ciudad de embarque.
#
# **Linea 4:** Con Seaborn creamos un grafico de violin a partir de los datos de titanic que nos separe por sexo en el eje *x* y nos realice un gráfico de las distribuciones de las edades.

# %%
titanic = sns.load_dataset("titanic")
fig, ax = plt.subplots(1,2,figsize = (12,5))
ax[0].bar(x=titanic.embark_town.value_counts().index, height=titanic.embark_town.value_counts())
sns.violinplot(data = titanic, y = "age", x = "sex")
plt.show()

# %% [markdown]
# # NIVEL AVANZADO: 2 puntos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ### Ejercicio 1
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
# Usando el dataset "diamonds" proveído por seaborn:
# <ul>
#     <li>Extrae una muestra de 1000 diamantes que tengan un corte (campo "cut") de tipo "Premium".</li>
#     <li>Usando la función de visualización de pandas basada en el algoritmo RadViz, analiza el comportamiento de la variable cualitatita "cut" en función de las variables cuantitativas "carat", "depth" y "price". Da a la figura un tamaño de (8, 8)</li>
# </ul>
# </div>

# %% [markdown]
# **Linea 1:** Cargamos el dataframe diamonds de Seaborn.
#
# **Linea 2:** Tomamos una muestra de 1000 elementos con **sample()** del dataframe diamons donde los valores de la columna cut sean igual a Premium.

# %%
diamonds = sns.load_dataset('diamonds')
diamonds = diamonds[diamonds["cut"] == "Premium"].sample(n = 1000)
diamonds.head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 19557   1.50  Premium     E     SI2   58.0   60.0   8190  7.52  7.47  4.35
# 3402    0.27  Premium     D     VS2   59.6   61.0    567  4.26  4.23  2.53
# 5418    1.05  Premium     H     SI2   63.0   57.0   3822  6.47  6.42  4.06
# 6273    1.12  Premium     E      I1   61.0   59.0   4014  6.74  6.70  4.10
# 27192   1.70  Premium     G     VS1   61.2   57.0  17492  7.73  7.64  4.70

# %% [markdown]
# **Linea 1:** Importamos la libreria radvidz desde pandas y su sublibreria plotting.
#
# **Linea 2:** Creamos la figura que va a contener nuestro gráfico y le asignamos su tamaño.
#
# **Linea 3:** Usamos radviz indicandole como fuente de datos las columnas seleccionadas de nuestro dataframe diamonds, de estas mismas le pedimos que tome la columna cut, por ultimo le damos un mapa de color.

# %%
from pandas.plotting import radviz
plt.figure(figsize=(8, 8))
radviz(diamonds[['carat', 'depth', 'price', 'cut']], 'cut', colormap='cool')
plt.show()

# %% [markdown]
# ### Ejercicio 2
# <div style="background:#5D6D7E;padding:20px;color:#ffffff;margin-top:10px;">
#     <p>El objetivo de este ejercicio es crear una función (a la que vamos a llamar "mask") que reciba dos argumentos: una imagen (con formato NumPy) y un umbral (valor real entre 0 y 1), y que devuelva otro array NumPy (otra imagen) que muestre puntos de color negro allí donde la imagen original "no sea suficientemente clara". Es decir, queremos obtener una máscara de la imagen.</p>
#     <p>Para ello se recomienda que la función:</p>
#     <ul>
#         <li>Compruebe si la imagen tiene tres o cuatro capas. En el caso de tener cuatro, la última (la capa de transparencia) deberá eliminarse.</li>
#         <li>Calcule el valor medio de las tres capas RGB (es decir, que cree un array con el ancho y alto de la imagen original en el que cada punto sea el valor medio de los tres valores RGB para dicho pixel</li>
#         <li>Por último, devuelva un array con las mismas dimensiones que el array generado en el paso anterior que contenga el valor 1 cuando el valor correspondiente en el array anterior sea un número superior al umbral indicado (segundo argumento pasado a la función), y 0 en caso contrario.</li>
#     </ul>
# </div>

# %% [markdown]
# **Linea 1:** Definimos la funcion mask que recibirá dos argumentos.
#
# **Linea 2:** Iniciamos nuestro primer bucle if en el cual verifica si la imagen tiene 4 capas.
#
# **Linea 3:** Si cumple la condicion anterior que se quede con todos los elementos de las 3 primeras capas.
#
# **Linea 4:** De toda la imagen queremos que nos tome las medias de cada una de las capas de color y la guarde en la variable media.
#
# **Linea 5:** Generamos la variable *mask1* que compara si la media tomada en la linea anterior es mayor o menor al umbral que se pasa como argumento y nos devuelve un 1 cuando la media sea mayor al umbral.

# %%
def mask(imagen, umbral):
    if imagen.shape[2] == 4:
        imagen = imagen[:, :, :3]

    media = np.mean(imagen, axis=2)
    mask1 = (media > umbral).astype(int)
    return mask1

# %% [markdown]
# <div style="background:#D8D8D8;padding:20px;color:#000000;margin-top:10px;">
# Descarga ahora la imagen indicada en la siguiente url y prueba ahora tu solución ejecutando las siguientes celdas:
# </div>

# %%
url = "https://www.interactivechaos.com/data/dog.png"

# %%
dog = plt.imread("dog.png")

# %%
plt.figure(figsize = (6, 6))
plt.imshow(dog)
plt.grid(False)
plt.show()

# %%
plt.figure(figsize = (6, 6))
plt.imshow(mask(dog, 0.99), cmap = "gray")
plt.show()

# %%
plt.figure(figsize = (6, 6))
plt.imshow(mask(dog, 0.75), cmap = "gray")
plt.show()

# %%
plt.figure(figsize = (6, 6))
plt.imshow(mask(dog, 0.50), cmap = "gray")
plt.show()
